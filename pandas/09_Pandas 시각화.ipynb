# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(2021)
df1 = pd.DataFrame(np.random.randn(100, 3),
                   index=pd.date_range('1/1/2021', periods=100),
                   columns=['A', 'B', 'C']).cumsum()
df1.tail()
# Out:
#                     A          B          C
# 2021-04-06  19.553541  11.530579  -8.757243
# 2021-04-07  20.909591  10.466816 -10.143565
# 2021-04-08  22.435144  11.674278  -7.474442
# 2021-04-09  22.546156  10.547727  -7.594791
# 2021-04-10  21.319639   9.825032  -8.213817

# %%
df1.plot() # 시각화

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# 폰트 설정
mpl.rc('font', family='AppleGothic')
# 유니코드에서  음수 부호설정
mpl.rc('axes', unicode_minus=False)

# %%
df1.plot()
plt.title("Pandas의 Plot메소드 사용 예")
plt.xlabel("시간")
plt.ylabel("Data")
plt.show()

# %% [markdown]
# ##plot 메서드의 kind라는 인수를 바꾸면 여러가지 플롯을 그릴 수 있다. 다음과 같은 인수값을 지원한다.
# ### - bar
# ### - pie
# ### - hist
# ### - kde
# ### - box
# ### - scatter
# ### - area

# %%
import seaborn as sns

iris = sns.load_dataset("iris")    # 붓꽃 데이터
titanic = sns.load_dataset("titanic")    # 타이타닉호 데이터

# %%
iris.sepal_length[:20].plot(kind='bar', rot=0)
plt.title("꽃받침의 길이 시각화")
plt.xlabel("Data")
plt.ylabel("꽃받침의 길이")
plt.show()

# %%
iris[:5].plot.bar(rot=0)
plt.title("Iris 데이터의 Bar Plot")
plt.xlabel("Data")
plt.ylabel("각 Feature의 값")
plt.ylim(0, 7)
plt.show()

# %%
df2 = iris.groupby(iris.species).mean()
df2.columns.name = 'feature'
df2
# Out:
# feature     sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
df2.plot.bar(rot=1)

# %%
iris[:5].plot.bar(rot=0)
plt.title("Iris 데이터의 Bar Plot")
plt.xlabel("Data")
plt.ylabel("각 Feature의 값")
plt.ylim(0, 7)
plt.show()

# %%
df2 = iris.groupby(iris.species).mean()
df2.columns.name = "feature"
df2
# Out:
# feature     sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
df2.T
# Out:
# species       setosa  versicolor  virginica
# feature
# sepal_length   5.006       5.936      6.588
# sepal_width    3.428       2.770      2.974
# petal_length   1.462       4.260      5.552
# petal_width    0.246       1.326      2.026

# %%
df2.plot.bar(rot=0)
plt.title("각 Feature의 품종 별 평균")
plt.xlabel("feature")
plt.ylabel("종")
plt.ylim(0, 8)
plt.show()

# %%
df3 = titanic['class'].value_counts()
df3
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %% [markdown]
# ## pie, hist, kde, box, scatter 플롯 예제

# %%
df3 = titanic.pclass.value_counts()
df3.plot.pie(autopct='%.2f%%')
plt.title("선실별 승객 수 비율")
plt.axis('equal')
plt.show()

# %%
iris.plot.hist()
plt.title("각 Feature 값들의 빈도수 Histogram")
plt.xlabel("데이터 값")
plt.show()

# %%
iris.boxplot(by='species')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbd5eae0350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbd5d6e5950>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbd5d260790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbd5d658790>]],
#       dtype=object)

# %%
iris.boxplot(by='species')
plt.tight_layout(pad=3, h_pad=1)
plt.show()
#이상치 확인
